# %%
import os
import pandas as pd
print(os.getcwd())

import os
for root, dirs, files in os.walk('.'):
    for f in files:
        if f.endswith('.csv'):
            print(os.path.join(root, f))

df = pd.read_csv("../../data/books_raw.csv")
# Out:
# c:\Users\hasan pc\OneDrive\Desktop\DS605_Lab1\bookscraper\bookscraper\spiders
